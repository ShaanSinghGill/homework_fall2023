# %%
import tensorflow as tf
from tensorboard.backend.event_processing import event_accumulator
import matplotlib.pyplot as plt
import numpy as np

# %%
log_file = 'data-small/q2_pg_cartpole_CartPole-v0_20-09-2023_19-24-47' # Replace with the path to your event log directory
event_acc = event_accumulator.EventAccumulator(log_file)
event_acc.Reload()
tags = event_acc.Tags()
# print(tags)
evals = [v.value for v in event_acc.Scalars('Eval_AverageReturn')]
steps = [v.value for v in  event_acc.Scalars('Train_EnvstepsSoFar')]
# Replace 'your_tag' with the tag you want to extract
log_file = 'data-small/q2_pg_cartpole_na_CartPole-v0_20-09-2023_19-25-17' # Replace with the path to your event log directory
event_acc = event_accumulator.EventAccumulator(log_file)
event_acc.Reload()
tags = event_acc.Tags()
# print(tags)
evals1 = [v.value for v in event_acc.Scalars('Eval_AverageReturn')]
steps1 = [v.value for v in  event_acc.Scalars('Train_EnvstepsSoFar')]
# Replace 'your_tag' with the tag you want to extract
log_file = 'data-small/q2_pg_cartpole_rtg_CartPole-v0_20-09-2023_19-25-01' # Replace with the path to your event log directory
event_acc = event_accumulator.EventAccumulator(log_file)
event_acc.Reload()
tags = event_acc.Tags()
# print(tags)
evals2 = [v.value for v in event_acc.Scalars('Eval_AverageReturn')]
steps2 = [v.value for v in  event_acc.Scalars('Train_EnvstepsSoFar')]
# Replace 'your_tag' with the tag you want to extract
log_file = 'data-small/q2_pg_cartpole_rtg_na_CartPole-v0_20-09-2023_19-25-31' # Replace with the path to your event log directory
event_acc = event_accumulator.EventAccumulator(log_file)
event_acc.Reload()
tags = event_acc.Tags()
# print(tags)
evals3 = [v.value for v in event_acc.Scalars('Eval_AverageReturn')]
steps3 = [v.value for v in  event_acc.Scalars('Train_EnvstepsSoFar')]
# Replace 'your_tag' with the tag you want to extract

# %%
plt.figure(figsize=(10, 5))
plt.plot(steps, evals, label='cartPole')
plt.plot(steps1, evals1, label='cartPole NA')
plt.plot(steps2, evals2, label='carPole RTG')
plt.plot(steps3, evals3, label='carPole RTG NA')
plt.xlabel('Train_EnvstepsSoFar')
plt.ylabel('Eval_AverageReturn')
plt.title('Eval_AverageReturn vs Train_EnvstepsSoFar')
plt.legend()
plt.grid(True)
plt.show()

# %%
log_file = 'data-big/q2_pg_cartpole_lb_CartPole-v0_20-09-2023_19-27-13' # Replace with the path to your event log directory
event_acc = event_accumulator.EventAccumulator(log_file)
event_acc.Reload()
tags = event_acc.Tags()
# print(tags)
evals = [v.value for v in event_acc.Scalars('Eval_AverageReturn')]
steps = [v.value for v in  event_acc.Scalars('Train_EnvstepsSoFar')]
log_file = 'data-big/q2_pg_cartpole_lb_na_CartPole-v0_20-09-2023_19-28-37' # Replace with the path to your event log directory
event_acc = event_accumulator.EventAccumulator(log_file)
event_acc.Reload()
tags = event_acc.Tags()
# print(tags)
evals1 = [v.value for v in event_acc.Scalars('Eval_AverageReturn')]
steps1 = [v.value for v in  event_acc.Scalars('Train_EnvstepsSoFar')]
# Replace 'your_tag' with the tag you want to extract
log_file = 'data-big/q2_pg_cartpole_lb_rtg_CartPole-v0_20-09-2023_19-27-55' # Replace with the path to your event log directory
event_acc = event_accumulator.EventAccumulator(log_file)
event_acc.Reload()
tags = event_acc.Tags()
# print(tags)
evals2 = [v.value for v in event_acc.Scalars('Eval_AverageReturn')]
steps2 = [v.value for v in  event_acc.Scalars('Train_EnvstepsSoFar')]
# Replace 'your_tag' with the tag you want to extract
log_file = 'data-big/q2_pg_cartpole_lb_rtg_na_CartPole-v0_20-09-2023_19-29-17' # Replace with the path to your event log directory
event_acc = event_accumulator.EventAccumulator(log_file)
event_acc.Reload()
tags = event_acc.Tags()
# print(tags)
evals3 = [v.value for v in event_acc.Scalars('Eval_AverageReturn')]
steps3 = [v.value for v in  event_acc.Scalars('Train_EnvstepsSoFar')]
# Replace 'your_tag' with the tag you want to extract
plt.figure(figsize=(10, 5))
plt.plot(steps, evals, label='cartPoleLB')
plt.plot(steps1, evals1, label='cartPoleLB NA')
plt.plot(steps2, evals2, label='carPoleLB RTG')
plt.plot(steps3, evals3, label='carPoleLB RTG NA')
plt.xlabel('Train_EnvstepsSoFar')
plt.ylabel('Eval_AverageReturn')
plt.title('Eval_AverageReturn LB vs Train_EnvstepsSoFar')
plt.legend()
plt.grid(True)
plt.show()

# %%
log_file = 'data-cheetah/q2_pg_cheetah_baseline_HalfCheetah-v4_20-09-2023_22-46-46' # Replace with the path to your event log directory
event_acc = event_accumulator.EventAccumulator(log_file)
event_acc.Reload()
tags = event_acc.Tags()
# print(tags)
evals = [v.value for v in event_acc.Scalars('Baseline_Loss')]
steps = [v.value for v in  event_acc.Scalars('Train_EnvstepsSoFar')]
# Replace 'your_tag' with the tag you want to extract
plt.figure(figsize=(10, 5))
plt.plot(steps, evals, label='cheetah baseline')
plt.xlabel('Train_EnvstepsSoFar')
plt.ylabel('Baseline_Loss')
plt.title('Baseline Loss vs Train_EnvstepsSoFar')
plt.legend()
plt.grid(True)
plt.show()

# %%
log_file = 'data/q2_pg_cheetah_baseline_HalfCheetah-v4_20-09-2023_22-46-46' # Replace with the path to your event log directory
event_acc = event_accumulator.EventAccumulator(log_file)
event_acc.Reload()
tags = event_acc.Tags()
# print(tags)
evals = [v.value for v in event_acc.Scalars('Eval_AverageReturn')]
steps = [v.value for v in  event_acc.Scalars('Train_EnvstepsSoFar')]
# Replace 'your_tag' with the tag you want to extract
plt.figure(figsize=(10, 5))
plt.plot(steps, evals, label='cheetah baseline')
plt.xlabel('Train_EnvstepsSoFar')
plt.ylabel('Eval_AverageReturn')
plt.title('Eval_AverageReturn vs Train_EnvstepsSoFar')
plt.legend()
plt.grid(True)
plt.show()

# %%
log_file = 'data/q2_pg_cheetah_baseline_HalfCheetah-v4_20-09-2023_22-59-09' # Replace with the path to your event log directory
event_acc = event_accumulator.EventAccumulator(log_file)
event_acc.Reload()
tags = event_acc.Tags()
# print(tags)
evals = [v.value for v in event_acc.Scalars('Eval_AverageReturn')]
steps = [v.value for v in  event_acc.Scalars('Train_EnvstepsSoFar')]
log_file = 'data/q2_pg_cheetah_baseline_HalfCheetah-v4_20-09-2023_23-02-45' # Replace with the path to your event log directory
event_acc = event_accumulator.EventAccumulator(log_file)
event_acc.Reload()
tags = event_acc.Tags()
# print(tags)
evals1 = [v.value for v in event_acc.Scalars('Eval_AverageReturn')]
steps1 = [v.value for v in  event_acc.Scalars('Train_EnvstepsSoFar')]

log_file = 'data/q2_pg_cheetah_baseline_HalfCheetah-v4_20-09-2023_23-07-51' # Replace with the path to your event log directory
event_acc = event_accumulator.EventAccumulator(log_file)
event_acc.Reload()
tags = event_acc.Tags()
# print(tags)
evals2 = [v.value for v in event_acc.Scalars('Eval_AverageReturn')]
steps2 = [v.value for v in  event_acc.Scalars('Train_EnvstepsSoFar')]

plt.figure(figsize=(10, 5))
plt.plot(steps, evals, label='0.001 BLR')
plt.plot(steps1, evals1, label='1 BGS')
plt.plot(steps2, evals2, label='0.001 LR and 1 BGS')


plt.xlabel('Train_EnvstepsSoFar')
plt.ylabel('Eval_AverageReturn')
plt.title('Eval_AverageReturn vs Train_EnvstepsSoFar')
plt.legend()
plt.grid(True)
plt.show()

# %%
log_file = 'data-cheetah/q2_pg_cheetah_baseline_HalfCheetah-v4_20-09-2023_22-59-09' # Replace with the path to your event log directory
event_acc = event_accumulator.EventAccumulator(log_file)
event_acc.Reload()
tags = event_acc.Tags()
# print(tags)
evals = [v.value for v in event_acc.Scalars('Baseline_Loss')]
steps = [v.value for v in  event_acc.Scalars('Train_EnvstepsSoFar')]
log_file = 'data-cheetah/q2_pg_cheetah_baseline_HalfCheetah-v4_20-09-2023_23-02-45' # Replace with the path to your event log directory
event_acc = event_accumulator.EventAccumulator(log_file)
event_acc.Reload()
tags = event_acc.Tags()
# print(tags)
evals1 = [v.value for v in event_acc.Scalars('Baseline_Loss')]
steps1 = [v.value for v in  event_acc.Scalars('Train_EnvstepsSoFar')]

log_file = 'data-cheetah/q2_pg_cheetah_baseline_HalfCheetah-v4_20-09-2023_23-07-51' # Replace with the path to your event log directory
event_acc = event_accumulator.EventAccumulator(log_file)
event_acc.Reload()
tags = event_acc.Tags()
# print(tags)
evals2 = [v.value for v in event_acc.Scalars('Baseline_Loss')]
steps2 = [v.value for v in  event_acc.Scalars('Train_EnvstepsSoFar')]

plt.figure(figsize=(10, 5))
plt.plot(steps, evals, label='0.001 BLR')
plt.plot(steps1, evals1, label='1 BGS')
plt.plot(steps2, evals2, label='0.001 LR and 1 BGS')


plt.xlabel('Train_EnvstepsSoFar')
plt.ylabel('Baseline Loss')
plt.title('Baseline vs Train_EnvstepsSoFar')
plt.legend()
plt.grid(True)
plt.show()

# %%
log_file = 'data-lunar/q2_pg_lunar_lander_lambda0_LunarLander-v2_20-09-2023_23-25-50' # Replace with the path to your event log directory
event_acc = event_accumulator.EventAccumulator(log_file)
event_acc.Reload()
evals = [v.value for v in event_acc.Scalars('Eval_AverageReturn')]
steps = [v.value for v in  event_acc.Scalars('Train_EnvstepsSoFar')]
log_file = 'data-lunar/q2_pg_lunar_lander_lambda0.95_LunarLander-v2_20-09-2023_23-26-16' # Replace with the path to your event log directory
event_acc = event_accumulator.EventAccumulator(log_file)
event_acc.Reload()
evals1 = [v.value for v in event_acc.Scalars('Eval_AverageReturn')]
steps1 = [v.value for v in  event_acc.Scalars('Train_EnvstepsSoFar')]

log_file = 'data-lunar/q2_pg_lunar_lander_lambda0.98_LunarLander-v2_20-09-2023_23-26-35' # Replace with the path to your event log directory
event_acc = event_accumulator.EventAccumulator(log_file)
event_acc.Reload()
evals2 = [v.value for v in event_acc.Scalars('Eval_AverageReturn')]
steps2 = [v.value for v in  event_acc.Scalars('Train_EnvstepsSoFar')]

log_file = 'data-lunar/q2_pg_lunar_lander_lambda0.99_LunarLander-v2_20-09-2023_23-27-37' # Replace with the path to your event log directory
event_acc = event_accumulator.EventAccumulator(log_file)
event_acc.Reload()
evals3 = [v.value for v in event_acc.Scalars('Eval_AverageReturn')]
steps3 = [v.value for v in  event_acc.Scalars('Train_EnvstepsSoFar')]

log_file = 'data-lunar/q2_pg_lunar_lander_lambda1_LunarLander-v2_20-09-2023_23-26-50' # Replace with the path to your event log directory
event_acc = event_accumulator.EventAccumulator(log_file)
event_acc.Reload()
evals4 = [v.value for v in event_acc.Scalars('Eval_AverageReturn')]
steps4 = [v.value for v in  event_acc.Scalars('Train_EnvstepsSoFar')]


plt.figure(figsize=(10, 5))
# plt.plot(steps, evals, label='0.00', linewidth =0.5)
# plt.plot(steps1, evals1, label='0.95', linewidth =0.5)
# plt.plot(steps2, evals2, label='0.98', linewidth =0.5)
# plt.plot(steps3, evals3, label='0.99', linewidth =0.5)
plt.plot(steps4, evals4, label='1.00', linewidth =0.5)

print(evals2[-1])

plt.xlabel('Train_EnvstepsSoFar')
plt.ylabel('Eval_AverageReturn')
plt.title('Eval_AverageReturn vs Train_EnvstepsSoFar')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# 240.85853576660156

# %%
log_file = 'data/q2_pg_pendulum_default_s1_InvertedPendulum-v4_21-09-2023_00-10-37' # Replace with the path to your event log directory
event_acc = event_accumulator.EventAccumulator(log_file)
event_acc.Reload()
evals = [v.value for v in event_acc.Scalars('Eval_AverageReturn')]
steps = [v.value for v in  event_acc.Scalars('Train_EnvstepsSoFar')]
log_file = 'data/q2_pg_pendulum_default_s2_InvertedPendulum-v4_21-09-2023_00-11-18' # Replace with the path to your event log directory
event_acc = event_accumulator.EventAccumulator(log_file)
event_acc.Reload()
evals1 = [v.value for v in event_acc.Scalars('Eval_AverageReturn')]
steps1 = [v.value for v in  event_acc.Scalars('Train_EnvstepsSoFar')]

log_file = 'data/q2_pg_pendulum_default_s3_InvertedPendulum-v4_21-09-2023_00-12-00' # Replace with the path to your event log directory
event_acc = event_accumulator.EventAccumulator(log_file)
event_acc.Reload()
evals2 = [v.value for v in event_acc.Scalars('Eval_AverageReturn')]
steps2 = [v.value for v in  event_acc.Scalars('Train_EnvstepsSoFar')]

log_file = 'data/q2_pg_pendulum_default_s4_InvertedPendulum-v4_21-09-2023_00-12-42' # Replace with the path to your event log directory
event_acc = event_accumulator.EventAccumulator(log_file)
event_acc.Reload()
evals3 = [v.value for v in event_acc.Scalars('Eval_AverageReturn')]
steps3 = [v.value for v in  event_acc.Scalars('Train_EnvstepsSoFar')]

log_file = 'data/q2_pg_pendulum_default_s5_InvertedPendulum-v4_21-09-2023_00-13-23' # Replace with the path to your event log directory
event_acc = event_accumulator.EventAccumulator(log_file)
event_acc.Reload()
evals4 = [v.value for v in event_acc.Scalars('Eval_AverageReturn')]
steps4 = [v.value for v in  event_acc.Scalars('Train_EnvstepsSoFar')]

log_file = 'data/q2_pg_pendulum_default_best_InvertedPendulum-v4_21-09-2023_23-41-51' # Replace with the path to your event log directory
event_acc = event_accumulator.EventAccumulator(log_file)
event_acc.Reload()
evals5 = [v.value for v in event_acc.Scalars('Eval_AverageReturn')]
steps5 = [v.value for v in  event_acc.Scalars('Train_EnvstepsSoFar')]


stacked_arrays = np.vstack((evals, evals1, evals2, evals3, evals4))
eaverages = np.mean(stacked_arrays, axis=0)
stacked_arrays = np.vstack((steps, steps1, steps2, steps3, steps4))
saverages = np.mean(stacked_arrays, axis=0)

plt.figure(figsize=(10, 5))
plt.plot(saverages, eaverages, label='averaged across seeds')
plt.plot(steps5, evals5, label='best')


first_crossing_index = eaverages.tolist().index(1000)
x_at_crossing = saverages.tolist()[first_crossing_index]
y_at_first_index_greater_than_1000 = eaverages.tolist()[first_crossing_index]

plt.annotate(f'Average First EvalReturn >= 1000, x = {x_at_crossing}', 
             xy=(x_at_crossing, y_at_first_index_greater_than_1000), 
             xytext=(15, -60), textcoords='offset points',
             arrowprops=dict(arrowstyle="->",
                             connectionstyle="arc3,rad=.2"))


first_crossing_index = evals5.index(1000)
x_at_crossing = steps5[first_crossing_index]
y_at_first_index_greater_than_1000 = evals5[first_crossing_index]

plt.annotate(f'Best Hyperparameter Eval return >= 1000, x = {x_at_crossing}', 
             xy=(x_at_crossing, y_at_first_index_greater_than_1000), 
             xytext=(15, -140), textcoords='offset points',
             arrowprops=dict(arrowstyle="->",
                             connectionstyle="arc3,rad=.2"))

plt.xlabel('Train_EnvstepsSoFar')
plt.ylabel('Eval_AverageReturn')
plt.title('Eval_AverageReturn vs Train_EnvstepsSoFar')
plt.legend()
plt.grid(True)
plt.show()

# %%
log_file = 'data/q2_pg_humanoid_Humanoid-v4_21-09-2023_01-06-55' # Replace with the path to your event log directory
event_acc = event_accumulator.EventAccumulator(log_file)
event_acc.Reload()
tags = event_acc.Tags()
# print(tags)
evals = [v.value for v in event_acc.Scalars('Eval_AverageReturn')]
steps = [v.value for v in  event_acc.Scalars('Train_EnvstepsSoFar')]
# Replace 'your_tag' with the tag you want to extract
plt.figure(figsize=(10, 5))
plt.plot(steps, evals, label='Humanoid')
plt.xlabel('Train_EnvstepsSoFar')
plt.ylabel('Eval_AverageReturn')
plt.title('Eval_AverageReturn vs Train_EnvstepsSoFar')
plt.xscale('log')
plt.legend()
plt.grid(True)
plt.show()
