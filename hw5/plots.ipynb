# %%
import tensorflow as tf
from tensorboard.backend.event_processing import event_accumulator
import matplotlib.pyplot as plt
import numpy as np

# %%
log_file = 'data/done/obstacles-cs285-v0_obstacles_multi_l2_h250_mpcrandom_horizon10_actionseq1000_24-10-2023_17-27-58'
event_acc = event_accumulator.EventAccumulator(log_file)
event_acc.Reload()
tags = event_acc.Tags()
evals1, steps1= [v.value for v in event_acc.Scalars('eval_return')], [v.step for v in event_acc.Scalars('eval_return')]

log_file = 'data/done/reacher-cs285-v0_reacher_multi_l2_h250_mpcrandom_horizon10_actionseq1000_25-10-2023_19-30-26'
event_acc = event_accumulator.EventAccumulator(log_file)
event_acc.Reload()
tags = event_acc.Tags()
evals2, steps2= [v.value for v in event_acc.Scalars('eval_return')], [v.step for v in event_acc.Scalars('eval_return')]

log_file = 'data/done/cheetah-cs285-v0_cheetah_multi_l2_h250_mpcrandom_horizon15_actionseq1000_25-10-2023_19-50-20'
event_acc = event_accumulator.EventAccumulator(log_file)
event_acc.Reload()
tags = event_acc.Tags()
evals3, steps3= [v.value for v in event_acc.Scalars('eval_return')], [v.step for v in event_acc.Scalars('eval_return')]




plt.figure(figsize=(10, 5))
plt.plot(steps1, evals1, label='Obstacle')
plt.plot(steps2, evals2, label='Reacher')
plt.plot(steps3, evals3, label='Cheetah')

plt.xlabel('epoch')
plt.ylabel('eval_return')
plt.title('eval_return vs step')
plt.legend()
plt.grid(True)
plt.show()

# %%
log_file = "data/reacher-cs285-v0_reacher_ablation_l2_h250_mpcrandom_horizon10_actionseq1000_02-11-2023_18-50-23"
# log_file = 'data/reacher/reacher-cs285-v0_reacher_ablation_l2_h250_mpcrandom_horizon10_actionseq1000_26-10-2023_01-41-18'
event_acc = event_accumulator.EventAccumulator(log_file)
event_acc.Reload()
tags = event_acc.Tags()
eval, step= [v.value for v in event_acc.Scalars('eval_return')], [v.step for v in event_acc.Scalars('eval_return')]

# log_file = "data/reacher-cs285-v0_reacher_ablation_l2_h250_mpcrandom_horizon10_actionseq1000_02-11-2023_17-27-00"
# log_file = 'data/reacher/reacher-cs285-v0_reacher_ablation_l2_h250_mpcrandom_horizon10_actionseq1000_26-10-2023_01-44-39'
log_file ='data/reacher-cs285-v0_reacher_ablation_l2_h250_mpcrandom_horizon5_actionseq1000_27-10-2023_11-00-27'
# log_file = "data/reacher/reacher-cs285-v0_reacher_ablation_l2_h250_mpcrandom_horizon10_actionseq500_26-10-2023_09-52-37"
event_acc = event_accumulator.EventAccumulator(log_file)
event_acc.Reload()
tags = event_acc.Tags()
evals2, steps2= [v.value for v in event_acc.Scalars('eval_return')], [v.step for v in event_acc.Scalars('eval_return')]

# log_file = "data/reacher-cs285-v0_reacher_ablation_l2_h250_mpcrandom_horizon10_actionseq1000_02-11-2023_17-42-00"
# log_file = 'data/reacher/reacher-cs285-v0_reacher_ablation_l2_h250_mpcrandom_horizon10_actionseq1000_26-10-2023_01-45-03'
log_file = 'data/reacher-cs285-v0_reacher_ablation_l2_h250_mpcrandom_horizon15_actionseq1000_27-10-2023_11-31-10'
# log_file = 'data/reacher/reacher-cs285-v0_reacher_ablation_l2_h250_mpcrandom_horizon10_actionseq1500_26-10-2023_09-52-44'
event_acc = event_accumulator.EventAccumulator(log_file)
event_acc.Reload()
tags = event_acc.Tags()
evals3, steps3= [v.value for v in event_acc.Scalars('eval_return')], [v.step for v in event_acc.Scalars('eval_return')]




plt.figure(figsize=(10, 5))
plt.plot(step, eval, label='Base: Horizon 10')
plt.plot(steps2, evals2, label='Horizon 5')
plt.plot(steps3, evals3, label='Horizon 15')

plt.xlabel('epoch')
plt.ylabel('eval_return')
plt.title('Horizon eval_return vs step')
plt.legend()
plt.grid(True)
plt.show()

# %%
log_file = 'data/ceetah2v4/cheetah-cs285-v0_cheetah_cem_l2_h250_mpccem_horizon15_actionseq1000_cem_iters4_26-10-2023_13-51-31' # Replace with the path to your event log directory
event_acc = event_accumulator.EventAccumulator(log_file)
event_acc.Reload()
tags = event_acc.Tags()
evals1, steps1= [v.value for v in event_acc.Scalars('eval_return')], [v.step for v in event_acc.Scalars('eval_return')]

# log_file = 'data/ceetah2v4/cheetah-cs285-v0_cheetah_cem_l2_h250_mpccem_horizon15_actionseq1000_cem_iters2_26-10-2023_17-10-01' # Replace with the path to your event log directory
log_file = 'data/done/cheetah-cs285-v0_cheetah_multi_l2_h250_mpcrandom_horizon15_actionseq1000_25-10-2023_19-50-20'
event_acc = event_accumulator.EventAccumulator(log_file)
event_acc.Reload()
tags = event_acc.Tags()
evals2, steps2= [v.value for v in event_acc.Scalars('eval_return')], [v.step for v in event_acc.Scalars('eval_return')]

plt.figure(figsize=(10, 5))
plt.plot(steps1, evals1, label='CEM 4')
plt.plot(steps2, evals2, label='Random Shooting')

plt.xlabel('epoch')
plt.ylabel('eval_return')
plt.title('Random Shooting VS CEM eval_return vs step')
plt.legend()
plt.grid(True)
plt.show()

# %%
log_file = 'data/sac/cheetah-cs285-v0_cheetah_mbpo_l2_h250_mpcrandom_horizon10_actionseq1000_26-10-2023_21-08-06'
event_acc = event_accumulator.EventAccumulator(log_file)
event_acc.Reload()
tags = event_acc.Tags()
evals1, steps1= [v.value for v in event_acc.Scalars('eval_return')], [v.step for v in event_acc.Scalars('eval_return')]

log_file = 'data/sac/cheetah-cs285-v0_cheetah_mbpo_l2_h250_mpcrandom_horizon10_actionseq1000_26-10-2023_22-16-42'
event_acc = event_accumulator.EventAccumulator(log_file)
event_acc.Reload()
tags = event_acc.Tags()
evals2, steps2= [v.value for v in event_acc.Scalars('eval_return')], [v.step for v in event_acc.Scalars('eval_return')]

log_file = 'data/sac/cheetah-cs285-v0_cheetah_mbpo_l2_h250_mpcrandom_horizon10_actionseq1000_26-10-2023_22-37-19'
event_acc = event_accumulator.EventAccumulator(log_file)
event_acc.Reload()
tags = event_acc.Tags()
evals3, steps3= [v.value for v in event_acc.Scalars('eval_return')], [v.step for v in event_acc.Scalars('eval_return')]




plt.figure(figsize=(10, 5))
plt.plot(steps1, evals1, label='SAC Baseline')
plt.plot(steps2, evals2, label='Dyna-like')
plt.plot(steps3, evals3, label='MBPO')

plt.xlabel('epoch')
plt.ylabel('eval_return')
plt.title('Problem 6 eval_return vs step')
plt.legend()
plt.grid(True)
plt.show()

# %%
log_file = 'data/hw3_dqn_dqn_CartPole-v1_s64_l2_d0.99_05-10-2023_20-31-52' # Replace with the path to your event log directory
event_acc = event_accumulator.EventAccumulator(log_file)
event_acc.Reload()
tags = event_acc.Tags()
evals1, steps1= [v.value for v in event_acc.Scalars('eval_return')], [v.step for v in event_acc.Scalars('eval_return')]

log_file = 'data/hw3_dqn_dqn_CartPole-v1_s64_l2_d0.99_05-10-2023_20-32-04' # Replace with the path to your event log directory
event_acc = event_accumulator.EventAccumulator(log_file)
event_acc.Reload()
tags = event_acc.Tags()
evals2, steps2= [v.value for v in event_acc.Scalars('eval_return')], [v.step for v in event_acc.Scalars('eval_return')]

log_file = 'data/hw3_dqn_dqn_CartPole-v1_s64_l2_d0.99_05-10-2023_20-32-29' # Replace with the path to your event log directory
event_acc = event_accumulator.EventAccumulator(log_file)
event_acc.Reload()
tags = event_acc.Tags()
evals3, steps3= [v.value for v in event_acc.Scalars('eval_return')], [v.step for v in event_acc.Scalars('eval_return')]

log_file = 'data/hw3_dqn_dqn_CartPole-v1_s64_l2_d0.99_05-10-2023_20-32-39' # Replace with the path to your event log directory
event_acc = event_accumulator.EventAccumulator(log_file)
event_acc.Reload()
tags = event_acc.Tags()
evals4, steps4= [v.value for v in event_acc.Scalars('eval_return')], [v.step for v in event_acc.Scalars('eval_return')]

plt.figure(figsize=(10, 5))
plt.plot(steps1, evals1, label='cartpole 0.00001')
plt.plot(steps2, evals2, label='cartpole 0.0001')
plt.plot(steps3, evals3, label='cartpole 0.01')
plt.plot(steps4, evals4, label='cartpole 0.1')
         
plt.xlabel('epoch')
plt.ylabel('eval_return')
plt.title('eval_return vs step')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NotFoundError                             Traceback (most recent call last)
# File ~/anaconda3/envs/cs285/lib/python3.10/site-packages/tensorboard/backend/event_processing/directory_watcher.py:88, in DirectoryWatcher.Load(self)
#      87 try:
# ---> 88     for event in self._LoadInternal():
#      89         yield event
#
# File ~/anaconda3/envs/cs285/lib/python3.10/site-packages/tensorboard/backend/event_processing/directory_watcher.py:110, in DirectoryWatcher._LoadInternal(self)
#     109 if not self._loader:
# --> 110     self._InitializeLoader()
#     112 # If it still doesn't exist, there is no data
#
# File ~/anaconda3/envs/cs285/lib/python3.10/site-packages/tensorboard/backend/event_processing/directory_watcher.py:173, in DirectoryWatcher._InitializeLoader(self)
#     172 def _InitializeLoader(self):
# --> 173     path = self._GetNextPath()
#     174     if path:
#
# File ~/anaconda3/envs/cs285/lib/python3.10/site-packages/tensorboard/backend/event_processing/directory_watcher.py:210, in DirectoryWatcher._GetNextPath(self)
#     200 """Gets the next path to load from.
#     201
#     202 This function also does the checking for out-of-order writes as it iterates
#    (...)
#     206   The next path to load events from, or None if there are no more paths.
#     207 """
#     208 paths = sorted(
#     209     path
# --> 210     for path in io_wrapper.ListDirectoryAbsolute(self._directory)
#     211     if self._path_filter(path)
#     212 )
#     213 if not paths:
#
# File ~/anaconda3/envs/cs285/lib/python3.10/site-packages/tensorboard/backend/event_processing/io_wrapper.py:78, in ListDirectoryAbsolute(directory)
#      73 """Yields all files in the given directory.
#      74
#      75 The paths are absolute.
#      76 """
#      77 return (
# ---> 78     os.path.join(directory, path) for path in tf.io.gfile.listdir(directory)
#      79 )
#
# File ~/anaconda3/envs/cs285/lib/python3.10/site-packages/tensorflow/python/lib/io/file_io.py:768, in list_directory_v2(path)
#     767 if not is_directory(path):
# --> 768   raise errors.NotFoundError(
#     769       node_def=None,
#     770       op=None,
#     771       message="Could not find directory {}".format(path))
#     773 # Convert each element to string, since the return values of the
#     774 # vector of string should be interpreted as strings, not bytes.
#
# NotFoundError: Could not find directory data/hw3_dqn_dqn_CartPole-v1_s64_l2_d0.99_05-10-2023_20-31-52
#
# During handling of the above exception, another exception occurred:
#
# DirectoryDeletedError                     Traceback (most recent call last)
# /Users/shaangill/Documents/GitHub/rl/homework_fall2023/hw4/plots.ipynb Cell 7 line 3
#       <a href='vscode-notebook-cell:/Users/shaangill/Documents/GitHub/rl/homework_fall2023/hw4/plots.ipynb#W6sZmlsZQ%3D%3D?line=0'>1</a> log_file = 'data/hw3_dqn_dqn_CartPole-v1_s64_l2_d0.99_05-10-2023_20-31-52' # Replace with the path to your event log directory
#       <a href='vscode-notebook-cell:/Users/shaangill/Documents/GitHub/rl/homework_fall2023/hw4/plots.ipynb#W6sZmlsZQ%3D%3D?line=1'>2</a> event_acc = event_accumulator.EventAccumulator(log_file)
# ----> <a href='vscode-notebook-cell:/Users/shaangill/Documents/GitHub/rl/homework_fall2023/hw4/plots.ipynb#W6sZmlsZQ%3D%3D?line=2'>3</a> event_acc.Reload()
#       <a href='vscode-notebook-cell:/Users/shaangill/Documents/GitHub/rl/homework_fall2023/hw4/plots.ipynb#W6sZmlsZQ%3D%3D?line=3'>4</a> tags = event_acc.Tags()
#       <a href='vscode-notebook-cell:/Users/shaangill/Documents/GitHub/rl/homework_fall2023/hw4/plots.ipynb#W6sZmlsZQ%3D%3D?line=4'>5</a> evals1, steps1= [v.value for v in event_acc.Scalars('eval_return')], [v.step for v in event_acc.Scalars('eval_return')]
#
# File ~/anaconda3/envs/cs285/lib/python3.10/site-packages/tensorboard/backend/event_processing/event_accumulator.py:246, in EventAccumulator.Reload(self)
#     238 """Loads all events added since the last call to `Reload`.
#     239
#     240 If `Reload` was never called, loads all events in the file.
#    (...)
#     243   The `EventAccumulator`.
#     244 """
#     245 with self._generator_mutex:
# --> 246     for event in self._generator.Load():
#     247         self._ProcessEvent(event)
#     248 return self
#
# File ~/anaconda3/envs/cs285/lib/python3.10/site-packages/tensorboard/backend/event_processing/directory_watcher.py:92, in DirectoryWatcher.Load(self)
#      90 except tf.errors.OpError:
#      91     if not tf.io.gfile.exists(self._directory):
# ---> 92         raise DirectoryDeletedError(
#      93             "Directory %s has been permanently deleted"
#      94             % self._directory
#      95         )
#
# DirectoryDeletedError: Directory data/hw3_dqn_dqn_CartPole-v1_s64_l2_d0.99_05-10-2023_20-31-52 has been permanently deleted

# %%
log_file = 'data/hw3_sac_reinforce1_HalfCheetah-v4_reinforce_s128_l3_alr0.0003_clr0.0003_b128_d0.99_t0.2_stu0.005_10-10-2023_00-23-05' # Replace with the path to your event log directory
event_acc = event_accumulator.EventAccumulator(log_file)
event_acc.Reload()
tags = event_acc.Tags()
evals = [v.value for v in event_acc.Scalars('eval_return')]
steps = [v.step for v in event_acc.Scalars('eval_return')]

log_file = 'data/hw3_sac_reinforce10_HalfCheetah-v4_reinforce_s128_l3_alr0.0003_clr0.0003_b128_d0.99_t0.2_stu0.005_10-10-2023_00-27-31' # Replace with the path to your event log directory
event_acc = event_accumulator.EventAccumulator(log_file)
event_acc.Reload()
tags = event_acc.Tags()
evals1 = [v.value for v in event_acc.Scalars('eval_return')]
steps1 = [v.step for v in event_acc.Scalars('eval_return')]


plt.figure(figsize=(10, 5))
plt.plot(steps, evals, label='cheetah1')
plt.plot(steps1, evals1, label='cheetah10')
plt.xlabel('eval_ep_len')
plt.ylabel('eval_return')
plt.title('eval_return vs step')
plt.legend()
plt.grid(True)
plt.show()

# %%
log_file = 'data/hw3_sac_reparametrize_HalfCheetah-v4_reparametrize_s128_l3_alr0.0003_clr0.0003_b128_d0.99_t0.1_stu0.005_11-10-2023_18-15-26' # Replace with the path to your event log directory
event_acc = event_accumulator.EventAccumulator(log_file)
event_acc.Reload()
tags = event_acc.Tags()
evals2 = [v.value for v in event_acc.Scalars('eval_return')]
steps2 = [v.step for v in event_acc.Scalars('eval_return')]


plt.figure(figsize=(10, 5))
plt.plot(steps, evals, label='cheetah1')
plt.plot(steps1, evals1, label='cheetah10')
plt.plot(steps2, evals2, label='cheetah reparam')

plt.xlabel('eval_ep_len')
plt.ylabel('eval_return')
plt.title('eval_return vs step')
plt.legend()
plt.grid(True)
plt.show()

# %%
log_file = 'data/hw3_sac_sac_humanoid_Humanoid-v4_reparametrize_s256_l3_alr0.0003_clr0.0003_b256_d0.99_t0.05_stu0.005_min_10-10-2023_01-35-34' # Replace with the path to your event log directory
event_acc = event_accumulator.EventAccumulator(log_file)
event_acc.Reload()
tags = event_acc.Tags()
evals = [v.value for v in event_acc.Scalars('eval_return')]
steps = [v.step for v in event_acc.Scalars('eval_return')]


plt.figure(figsize=(10, 5))
plt.plot(steps, evals, label='humanoid')

plt.xlabel('eval_ep_len')
plt.ylabel('eval_return')
plt.title('eval_return vs step')
plt.legend()
plt.grid(True)
plt.show()

# %%
log_file = 'data/hw3_sac_sac_humanoid_Humanoid-v4_reparametrize_s256_l3_alr0.0003_clr0.0003_b256_d0.99_t0.05_stu0.005_min_10-10-2023_13-57-34' # Replace with the path to your event log directory
event_acc = event_accumulator.EventAccumulator(log_file)
event_acc.Reload()
tags = event_acc.Tags()
evals = [v.value for v in event_acc.Scalars('eval_return')]
steps = [v.step for v in event_acc.Scalars('eval_return')]


log_file = 'data/hw2_humanoid' # Replace with the path to your event log directory
event_acc = event_accumulator.EventAccumulator(log_file)
event_acc.Reload()
tags = event_acc.Tags()
evals1 = [v.value for v in event_acc.Scalars('Eval_AverageReturn')]
steps1 = [v.value for v in event_acc.Scalars('Train_EnvstepsSoFar')]


plt.figure(figsize=(10, 5))
plt.plot(steps, evals, label='humanoid off-policy')
plt.plot(steps1, evals1, label='humanoid on-policy')

plt.xlabel('env steps')
plt.ylabel('eval_return')
plt.title('eval_return vs step')
plt.legend()
plt.grid(True)
plt.show()

# %%
max(steps1)
max(steps)
# Out:
# 695000

# %%
log_file = 'data/hw3_sac_sac_hopper_singlecritic_Hopper-v4_reparametrize_s128_l3_alr0.0003_clr0.0003_b256_d0.99_t0.05_stu0.005_10-10-2023_10-33-31' # Replace with the path to your event log directory
event_acc = event_accumulator.EventAccumulator(log_file)
event_acc.Reload()
tags = event_acc.Tags()
evals = [v.value for v in event_acc.Scalars('q_values')]
steps = [v.step for v in event_acc.Scalars('q_values')]


log_file = 'data/hw3_sac_sac_hopper_doubleq_Hopper-v4_reparametrize_s128_l3_alr0.0003_clr0.0003_b256_d0.99_t0.05_stu0.005_doubleq_11-10-2023_18-06-11' # Replace with the path to your event log directory
event_acc = event_accumulator.EventAccumulator(log_file)
event_acc.Reload()
tags = event_acc.Tags()
evals1 = [v.value for v in event_acc.Scalars('q_values')]
steps1 = [v.step for v in event_acc.Scalars('q_values')]



log_file = 'data/hw3_sac_sac_hopper_clipq_Hopper-v4_reparametrize_s128_l3_alr0.0003_clr0.0003_b256_d0.99_t0.05_stu0.005_min_11-10-2023_19-03-52' # Replace with the path to your event log directory
event_acc = event_accumulator.EventAccumulator(log_file)
event_acc.Reload()
tags = event_acc.Tags()
evals2 = [v.value for v in event_acc.Scalars('q_values')]
steps2 = [v.step for v in event_acc.Scalars('q_values')]


plt.figure(figsize=(10, 5))
plt.plot(steps, evals, label='single critic')
plt.plot(steps1, evals1, label='double critic')
plt.plot(steps2, evals2, label='clipq')


plt.xlabel('env steps')
plt.ylabel('q_value')
plt.title('q_value vs step')
plt.legend()
plt.grid(True)
plt.show()
